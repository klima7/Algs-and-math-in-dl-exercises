# %% [markdown]
# # Algorytmika i matematyka uczenia maszynowego
# ## Laboratorium 1
#
# **UWAGA**: W niniejszym laboratorium proszę nie korzystać z zewnętrzych modułów/bibliotek.
#
# ### Zad 1:
#
# Zaimplementuj funkcję:
# $f(x) = \frac{1}{8}x^{4} + 2(x + 0.7)^{3} - \frac{1}{2}x^{2} - 38 x + 1$

# %%
def f(x):
    return 1/8 * x**4 + 2 * (x + 0.7)**3 - 1/2 * x**2 - 38 * x + 1

# %% [markdown]
# ### Zad 2:
#
# Oblicz wartosc funkcji $f(x)$ w przedziale [-20, 20] z krokiem 1 ($\Delta$).

# %%
x = list(range(-20, 21))
y = [f(i) for i in x]
print(y)
# Out:
# [6182.885999999999, 4575.650999999998, 3289.565999999999, 2281.1309999999994, 1509.8459999999986, 938.2109999999993, 531.7259999999997, 258.89099999999917, 91.20599999999968, 3.170999999999367, -27.714000000000397, -20.949000000000296, 6.966000000000008, 42.53100000000006, 75.24600000000004, 97.61100000000002, 105.126, 96.291, 72.606, 38.571, 1.686, -27.549, -35.63399999999999, -6.068999999999988, 80.64600000000002, 247.01100000000002, 518.5260000000001, 923.691, 1494.0059999999996, 2263.9709999999995, 3271.0859999999993, 4555.850999999999, 6161.766, 8135.330999999998, 10526.045999999998, 13386.411, 16771.926, 20741.091, 25355.406, 30679.371, 36780.486]

# %% [markdown]
# ### Zad 3:
#
# Wyświetl wykres funkcji $f(x)$.

# %%
import matplotlib.pyplot as plt
plt.plot(x, y)
plt.grid()

# %% [markdown]
# ### Zad 4:
#
# Znajdź taką wartość $x$ (w przedziale _[-20, 20]_), dla której funkcja $f(x)$ przyjmuje najmniejszą wartość.

# %%
y1_min, x1_min = sorted(zip(y, x))[0]
print(f'Xmin = {x1_min}\nYmin = {y1_min}')
# Out:
# Xmin = 2
# Ymin = -35.63399999999999

# %% [markdown]
# ### Zad 5:
#
# Wyznacz inną liczbę przedziałów (inny krok ($\Delta$)) z zakresu _[-20, 20]_ i sprawdź czy odnajdziesz mniejszą wartość minimalną funkcji $f(x)$ niż w poprzednim zadaniu? Jeżeli tak to podaj wartość $x$ dla której znalazłeś najmniejszą wartość funkcji $f(x)$.

# %%
delta = 0.01
x2 = [i*delta-20 for i in range(int(40/delta)+1)]
y2 = [f(i) for i in x2]
y2_min, x2_min = sorted(zip(y2, x2))[0]
print(f'Xmin = {x2_min}\nYmin = {y2_min}')
# Out:
# Xmin = 1.7800000000000011
# Ymin = -36.463371179999996

# %% [markdown]
# ### Zad 6:
#
# Wyświetl wykres (parametry wykresu dobierz samodzielnie) prezentujący minimum funkcji $f(x)$

# %%
import matplotlib.pyplot as plt
plt.plot(x2, y2)
plt.scatter([x2_min], [y2_min], c='r')
plt.xlim([1.5, 2])
plt.ylim([-40, 4])
plt.grid()

# %% [markdown]
# ### Zad 7:
#
# Znajdź taką wartość $x$ (w przedziale _[-20, 20])_, dla której funkcja $f(x)$ przyjmuje najmniejszą wartość.
# W tym zadaniu wygeneruj $k$ losowych wartości $x$ (metoda Monte Carlo).
# Wyświetl wykres funkcji.

# %%
import random
k = 50

x3 = [random.uniform(-20, 20) for i in range(k)]
y3 = [f(i) for i in x3]

tmp = sorted(zip(x3, y3))
x3_sorted = [t[0] for t in tmp]
y3_sorted = [t[1] for t in tmp]

plt.plot(x3_sorted, y3_sorted)
plt.grid()
plt.xlim([-20, 20])

y3_min, x3_min = sorted(zip(y3, x3))[0]
print(f'Xmin = {x3_min}\nYmin = {y3_min}')
# Out:
# Xmin = 1.8763620978106523
# Ymin = -36.310743676554395
